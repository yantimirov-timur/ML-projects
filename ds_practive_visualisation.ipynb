# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
genome_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv')
heat_map = pd.pivot_table(genome_stat, values=['species0', 'species1', 'species2', 'species3', 'species4'],
                     index=['Unnamed: 0'])
        
#heatmap_plot = sns.heatmap(genome_stat, center=0,cmap="viridis")

sns.heatmap(heat_map, cmap="viridis")
# Out:
# <AxesSubplot:ylabel='Unnamed: 0'>

# %%
dota_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')
dota_stat['number_of_roles'] = dota_stat.roles.str.count(',')+1


dota_stat.number_of_roles.hist()
# Out:
# <AxesSubplot:>

# %%
iris_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv')
# iris_stat_sepal_l = iris_stat['sepal length']
# iris_stat_sepal_w = iris_stat['sepal width']
# iris_stat_petal_l = iris_stat['petal length']
# iris_stat_petal_w = iris_stat['petal width']
# sns.kdeplot(iris_stat_sepal_l, label = 'sepal length')
# sns.kdeplot(iris_stat_sepal_w, label = 'sepal width')
# sns.kdeplot(iris_stat_petal_l, label = 'petal length')
# sns.kdeplot(iris_stat_petal_w, label = 'petal width')
# plt.legend()


# sns.displot(iris_stat_sepal_l)
# sns.displot(iris_stat_sepal_w)
# sns.displot(iris_stat_petal_l)
# sns.displot(iris_stat_petal_w)
# #3.6 2.4 
# iris_stat_petal_l.max()-iris_stat_petal_l.min()

# %%
iris_stat_sepal_l = iris_stat['sepal length']
iris_stat_sepal_w = iris_stat['sepal width']
iris_stat_petal_l = iris_stat['petal length']
iris_stat_petal_w = iris_stat['petal width']


sns.pairplot(iris_stat)
